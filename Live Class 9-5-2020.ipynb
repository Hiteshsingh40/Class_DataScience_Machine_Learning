# %% [markdown]
# # EDA

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
x=['sun','mon','fri','sat','tue','wed','thu']
y=[5,6.7,4,6,2,4.9,1.8]

# %%
ax=sns.stripplot(x,y)
ax.set(xlabel='Days',ylabel='Amount_spend')
plt.title ('My first graph')
plt.show()

# %%
sns.violinplot?

# %%
# Load the data

ds=pd.read_csv('emptest.csv')
print(ds.head())

# create violinplot 
sns.violinplot(x='Salary',data=ds)
#show the plot
plt.show()
# Out:
#    SNo    Name  Age       City   Salary
# 0    1     Tom   28    Toronto  20000.0
# 1    2     Lee   32   HongKong   3000.0
# 2    3  Steven   43    BayArea   8300.0
# 3    4     Ram   38  Hyderabad   3900.0
# 4    5    Dave   34    Toronto   8000.0

# %%
sns.violinplot(x='Age',data=ds)

# %%
dsiris=pd.read_csv('iris.csv')
print(dsiris)
print(dsiris.head())
sns.set(style='whitegrid')
ax=sns.stripplot(x='class',y='sepal length',data=dsiris);
plt.title('Graph')
plt.show()
# Out:
#      sepal length  sepal width  petal length  petal width           class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]
# ...

# %%
ax=sns.swarmplot(x='class',y='sepal length',data=dsiris);
plt.title('Graph')
plt.show()

# %%
sns.get_dataset_names()
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1318                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1319                           encode_chunked=req.has_header('Transfer-encoding'))
#    1320             except OSError as err: # timeout error
#
# C:\ProgramData\Anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1251         """Send a complete request to the server."""
# -> 1252         self._send_request(method, url, body, headers, encode_chunked)
#    1253
#
# C:\ProgramData\Anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1297             body = _encode(body, 'body')
# -> 1298         self.endheaders(body, encode_chunked=encode_chunked)
# ...

# %%
flights=sns.load_dataset('flights')
flights.head(5)
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
flights.passengers.hist(bins=5)

# %%
flights.passengers.hist(bins=20)

# %%
flights.passengers.describe()
# Out:
# count    144.000000
# mean     280.298611
# std      119.966317
# min      104.000000
# 25%      180.000000
# 50%      265.500000
# 75%      360.500000
# max      622.000000
# Name: passengers, dtype: float64

# %%
sns.boxplot(x=flights.passengers)

# %%
# Load data
titanicds=sns.load_dataset('titanic')
print(titanicds)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanicds.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
titanicds['class']
# Out:
# 0       Third
# 1       First
# 2       Third
# 3       First
# 4       Third
#         ...
# 886    Second
# 887     First
# 888     Third
# 889     First
# 890     Third
# Name: class, Length: 891, dtype: category
# Categories (3, object): [First, Second, Third]

# %%
titanicds['class'].value_counts()
# Out:
# Third     491
# First     216
# Second    184
# Name: class, dtype: int64

# %%
sns.countplot(titanicds['class'])

# %%
sns.catplot?

# %%
# set up a category plot
g=sns.catplot(x='class',y='survived',hue='sex',data=titanicds,kind='bar')
# show plot
plt.show()

# %%
# set up a category plot
g=sns.catplot(x='class',y='survived',hue='sex',data=titanicds,kind='violin')

#show plot
plt.show()

# %%
import seaborn as sns
sns.set(style='ticks')
exercise=sns.load_dataset('exercise')
g=sns.catplot(x='time',y='pulse',hue='kind',data=exercise)

# %%
sns.get_dataset_names()
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1318                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1319                           encode_chunked=req.has_header('Transfer-encoding'))
#    1320             except OSError as err: # timeout error
#
# C:\ProgramData\Anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1251         """Send a complete request to the server."""
# -> 1252         self._send_request(method, url, body, headers, encode_chunked)
#    1253
#
# C:\ProgramData\Anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1297             body = _encode(body, 'body')
# -> 1298         self.endheaders(body, encode_chunked=encode_chunked)
# ...

# %%
sns.load_dataset('tips')
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# load the data
tips=sns.load_dataset('tips')
print(tips.head())
# create violinplot
sns.violinplot(x='total_bill',data=tips)
# show the plot
plt.show()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.distplot?

# %%
sns.distplot(tips['tip'],bins=20)

# %%
sns.distplot(tips['total_bill'])

# %%
sns.distplot(tips['total_bill'],bins=100)

# %%
sns.distplot(tips['total_bill'],bins=50,kde=False)

# %%
irisds=sns.load_dataset('iris')
irisds
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# Impot neccesary libraries
# Reset default params
sns.set()
# set context to 'paper'
sns.set_context('paper')
# Load iris data
iris=sns.load_dataset('iris')

# construct iris plot
sns.swarmplot(x='species',y='petal_length',data=iris)

# show plot
plt.show()

# %% [raw]
# # sns.get_dataset_names()

# %%
sns.get_dataset_names()
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\urllib\request.py in do_open(self, http_class, req, **http_conn_args)
#    1318                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1319                           encode_chunked=req.has_header('Transfer-encoding'))
#    1320             except OSError as err: # timeout error
#
# C:\ProgramData\Anaconda3\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1251         """Send a complete request to the server."""
# -> 1252         self._send_request(method, url, body, headers, encode_chunked)
#    1253
#
# C:\ProgramData\Anaconda3\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1297             body = _encode(body, 'body')
# -> 1298         self.endheaders(body, encode_chunked=encode_chunked)
# ...

# %%
mpgds=sns.load_dataset('mpg')
mpgds
# Out:
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# <ipython-input-40-0c3ee9341049> in <module>
# ----> 1 mpgds=sns.load_dataset('mpg')
#       2 mpgds
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\utils.py in load_dataset(name, cache, data_home, **kws)
#     437         full_path = cache_path
#     438
# --> 439     df = pd.read_csv(full_path, **kws)
#     440     if df.iloc[-1].isnull().all():
#     441         df = df.iloc[:-1]
#
# ...

# %%
sns.scatterplot(data=mpgds,x='mpg',y='weight')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-3517bb06f72e> in <module>
# ----> 1 sns.scatterplot(data=mpgds,x='mpg',y='weight')
#
# NameError: name 'mpgds' is not defined

# %%
sns.scatterplot(data=mpgds,x='horse power',y='mpg')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-cdc3d1d562b8> in <module>
# ----> 1 sns.scatterplot(data=mpgds,x='horse power',y='mpg')
#
# NameError: name 'mpgds' is not defined

# %%
sns.joinplot(data=mpgds,x='weight',y='mpg')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-dca2a95e8ea1> in <module>
# ----> 1 sns.joinplot(data=mpgds,x='weight',y='mpg')
#
# AttributeError: module 'seaborn' has no attribute 'joinplot'

# %%
sns.joinplot(data=mpgds,x='weight',y='mpg',kind='kide')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-80d8575e61f9> in <module>
# ----> 1 sns.joinplot(data=mpgds,x='weight',y='mpg',kind='kide')
#
# AttributeError: module 'seaborn' has no attribute 'joinplot'

# %%
sns.jointplot(data=mpgds,x='weight',y='mpg',kind='hex')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-1cb0e1b2b1bd> in <module>
# ----> 1 sns.jointplot(data=mpgds,x='weight',y='mpg',kind='hex')
#
# NameError: name 'mpgds' is not defined

# %%
sns.stripplot(data=mpgds,x='origin',y='mpg',)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-dc65c977f00b> in <module>
# ----> 1 sns.stripplot(data=mpgds,x='origin',y='mpg',)
#
# NameError: name 'mpgds' is not defined

# %%
sns.swarmplot(data=mpgds,x='origin',y='mpg')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-47-3bb1401b8ddf> in <module>
# ----> 1 sns.swarmplot(data=mpgds,x='origin',y='mpg')
#
# NameError: name 'mpgds' is not defined

# %%
sns.catplot?

# %%
sns.catplot(data=mpgds,x='origin',y='mpg',kind='box')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-97ba867b4200> in <module>
# ----> 1 sns.catplot(data=mpgds,x='origin',y='mpg',kind='box')
#
# NameError: name 'mpgds' is not defined

# %%
sns.pairplot(mpgds)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-6a89ee761937> in <module>
# ----> 1 sns.pairplot(mpgds)
#
# NameError: name 'mpgds' is not defined

# %%
sns.heatmap?

# %%
flights=sns.load_dataset('flights')
flights=flights.pivot('month','year','passenger')
flights
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'passenger'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-52-22e0894b4c6d> in <module>
# ...

# %%
sns.heatmap()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-53-41226c95812c> in <module>
# ----> 1 sns.heatmap()
#
# TypeError: heatmap() missing 1 required positional argument: 'data'

# %%
ax=sns.heatmap(flights)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-54-863c908b715d> in <module>
# ----> 1 ax=sns.heatmap(flights)
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     510     plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     511                           annot_kws, cbar, cbar_kws, xticklabels,
# --> 512                           yticklabels, mask)
#     513
#     514     # Add the pcolormesh kwargs here
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\matrix.py in __init__(self, data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, cbar, cbar_kws, xticklabels, yticklabels, mask)
# ...

# %%
titanicds
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...
